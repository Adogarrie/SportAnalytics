# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
#scrape a single game shots. We will allow users to enter a base url
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id: 27071

# %%
#Use requests to get the webpage and BeautifulSoup to parse the page
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
#get only the shotsData
strings = scripts[1].string

# %%
# strip unnecessary symbols and get only JSON data 
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

data
# Out:
# {'h': [{'id': '595245',
#    'minute': '8',
#    'result': 'MissedShots',
#    'X': '0.9369999694824219',
#    'Y': '0.3220000076293945',
#    'xG': '0.008404449559748173',
#    'player': 'Alex Kral',
#    'h_a': 'h',
#    'player_id': '8017',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Irvin Cardona',
#    'lastAction': 'Aerial'},
#   {'id': '595246',
#    'minute': '17',
#    'result': 'Goal',
#    'X': '0.96',
#    'Y': '0.5159999847412109',
#    'xG': '0.595239520072937',
#    'player': 'Marash Kumbulla',
#    'h_a': 'h',
#    'player_id': '6324',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Jofre Carreras',
#    'lastAction': 'Cross'},
#   {'id': '595247',
#    'minute': '21',
#    'result': 'MissedShots',
#    'X': '0.7580000305175781',
#    'Y': '0.605999984741211',
#    'xG': '0.0327371284365654',
#    'player': 'Irvin Cardona',
#    'h_a': 'h',
#    'player_id': '5724',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': None,
#    'lastAction': 'BallRecovery'},
#   {'id': '595248',
#    'minute': '23',
#    'result': 'MissedShots',
#    'X': '0.875999984741211',
#    'Y': '0.509000015258789',
#    'xG': '0.06002368777990341',
#    'player': 'Alejo Véliz',
#    'h_a': 'h',
#    'player_id': '12105',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Pol Lozano',
#    'lastAction': 'Cross'},
#   {'id': '595249',
#    'minute': '26',
#    'result': 'MissedShots',
#    'X': '0.7390000152587891',
#    'Y': '0.605',
#    'xG': '0.02612685039639473',
#    'player': 'Carlos Romero',
#    'h_a': 'h',
#    'player_id': '11402',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Pol Lozano',
#    'lastAction': 'Pass'},
#   {'id': '595251',
#    'minute': '34',
#    'result': 'MissedShots',
#    'X': '0.7880000305175782',
#    'Y': '0.6869999694824219',
#    'xG': '0.027402915060520172',
#    'player': 'Jofre Carreras',
#    'h_a': 'h',
#    'player_id': '10209',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Pol Lozano',
#    'lastAction': 'Pass'},
#   {'id': '595252',
#    'minute': '46',
#    'result': 'Goal',
#    'X': '0.81',
#    'Y': '0.4620000076293945',
#    'xG': '0.09480568766593933',
#    'player': 'Jofre Carreras',
#    'h_a': 'h',
#    'player_id': '10209',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Irvin Cardona',
#    'lastAction': 'Pass'},
#   {'id': '595254',
#    'minute': '54',
#    'result': 'SavedShot',
#    'X': '0.8780000305175781',
#    'Y': '0.6780000305175782',
#    'xG': '0.10381416976451874',
#    'player': 'Irvin Cardona',
#    'h_a': 'h',
#    'player_id': '5724',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Jofre Carreras',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '595250',
#    'minute': '31',
#    'result': 'BlockedShot',
#    'X': '0.7830000305175782',
#    'Y': '0.46099998474121096',
#    'xG': '0.10645518451929092',
#    'player': 'Johan Mojica',
#    'h_a': 'a',
#    'player_id': '6242',
#    'situation': 'DirectFreekick',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '595253',
#    'minute': '52',
#    'result': 'SavedShot',
#    'X': '0.8519999694824218',
#    'Y': '0.4209999847412109',
#    'xG': '0.017439324408769608',
#    'player': 'Sergi Darder',
#    'h_a': 'a',
#    'player_id': '2621',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Pablo Maffeo',
#    'lastAction': 'Aerial'},
#   {'id': '595255',
#    'minute': '61',
#    'result': 'SavedShot',
#    'X': '0.925',
#    'Y': '0.5120000076293946',
#    'xG': '0.41466960310935974',
#    'player': 'Abdón Prats',
#    'h_a': 'a',
#    'player_id': '8014',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Raíllo',
#    'lastAction': 'HeadPass'},
#   {'id': '595256',
#    'minute': '67',
#    'result': 'MissedShots',
#    'X': '0.975',
#    'Y': '0.43',
#    'xG': '0.1059073656797409',
#    'player': 'Cyle Larin',
#    'h_a': 'a',
#    'player_id': '11340',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': None,
#    'lastAction': 'Challenge'},
#   {'id': '595257',
#    'minute': '67',
#    'result': 'Goal',
#    'X': '0.9830000305175781',
#    'Y': '0.4759999847412109',
#    'xG': '0.95011305809021',
#    'player': 'Raíllo',
#    'h_a': 'a',
#    'player_id': '2584',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'OtherBodyPart',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Cyle Larin',
#    'lastAction': 'None'},
#   {'id': '595258',
#    'minute': '81',
#    'result': 'BlockedShot',
#    'X': '0.7569999694824219',
#    'Y': '0.4570000076293945',
#    'xG': '0.02196209318935871',
#    'player': 'Samú Costa',
#    'h_a': 'a',
#    'player_id': '10974',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '595259',
#    'minute': '88',
#    'result': 'SavedShot',
#    'X': '0.9180000305175782',
#    'Y': '0.5479999923706055',
#    'xG': '0.05091835930943489',
#    'player': 'Raíllo',
#    'h_a': 'a',
#    'player_id': '2584',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Pablo Maffeo',
#    'lastAction': 'Card'},
#   {'id': '595260',
#    'minute': '91',
#    'result': 'SavedShot',
#    'X': '0.9730000305175781',
#    'Y': '0.34',
#    'xG': '0.050787560641765594',
#    'player': 'Chiquinho',
#    'h_a': 'a',
#    'player_id': '10327',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Toni Lato',
#    'lastAction': 'CornerAwarded'},
#   {'id': '595261',
#    'minute': '91',
#    'result': 'BlockedShot',
#    'X': '0.8959999847412109',
#    'Y': '0.63',
#    'xG': '0.019314588978886604',
#    'player': 'Raíllo',
#    'h_a': 'a',
#    'player_id': '2584',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Chiquinho',
#    'lastAction': 'Cross'},
#   {'id': '595262',
#    'minute': '97',
#    'result': 'BlockedShot',
#    'X': '0.8519999694824218',
#    'Y': '0.40099998474121096',
#    'xG': '0.024302851408720016',
#    'player': 'Manuel Morlanes',
#    'h_a': 'a',
#    'player_id': '6592',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Raíllo',
#    'lastAction': 'Aerial'},
#   {'id': '595263',
#    'minute': '100',
#    'result': 'MissedShots',
#    'X': '0.8530000305175781',
#    'Y': '0.5970000076293945',
#    'xG': '0.03651612624526024',
#    'player': 'Abdón Prats',
#    'h_a': 'a',
#    'player_id': '8014',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27071',
#    'h_team': 'Espanyol',
#    'a_team': 'Mallorca',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-10-05 12:00:00',
#    'player_assisted': 'Toni Lato',
#    'lastAction': 'Cross'}]}

# %%
x = []
y = []
xG = []
result = []
player_assisted = []
team = []
data_away = data['a']
data_home = data['h']
player = []
situation = []
shotType = []

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_away[index][key])

# %%
col_names = ['x','y','xG','result','team']
df = pd.DataFrame([x,y,xG,result,team],index=col_names)
df = df.T

df
# Out:
#                      x                    y                    xG  \
# 0   0.9369999694824219   0.3220000076293945  0.008404449559748173
# 1                 0.96   0.5159999847412109     0.595239520072937
# 2   0.7580000305175781    0.605999984741211    0.0327371284365654
# 3    0.875999984741211    0.509000015258789   0.06002368777990341
# 4   0.7390000152587891                0.605   0.02612685039639473
# 5   0.7880000305175782   0.6869999694824219  0.027402915060520172
# 6                 0.81   0.4620000076293945   0.09480568766593933
# 7   0.8780000305175781   0.6780000305175782   0.10381416976451874
# 8   0.7830000305175782  0.46099998474121096   0.10645518451929092
# 9   0.8519999694824218   0.4209999847412109  0.017439324408769608
# 10               0.925   0.5120000076293946   0.41466960310935974
# 11               0.975                 0.43    0.1059073656797409
# 12  0.9830000305175781   0.4759999847412109      0.95011305809021
# 13  0.7569999694824219   0.4570000076293945   0.02196209318935871
# 14  0.9180000305175782   0.5479999923706055   0.05091835930943489
# 15  0.9730000305175781                 0.34  0.050787560641765594
# 16  0.8959999847412109                 0.63  0.019314588978886604
# 17  0.8519999694824218  0.40099998474121096  0.024302851408720016
# 18  0.8530000305175781   0.5970000076293945   0.03651612624526024
#
#          result      team
# 0   MissedShots  Espanyol
# 1          Goal  Espanyol
# 2   MissedShots  Espanyol
# 3   MissedShots  Espanyol
# 4   MissedShots  Espanyol
# 5   MissedShots  Espanyol
# 6          Goal  Espanyol
# 7     SavedShot  Espanyol
# 8   BlockedShot  Mallorca
# 9     SavedShot  Mallorca
# 10    SavedShot  Mallorca
# 11  MissedShots  Mallorca
# 12         Goal  Mallorca
# 13  BlockedShot  Mallorca
# 14    SavedShot  Mallorca
# 15    SavedShot  Mallorca
# 16  BlockedShot  Mallorca
# 17  BlockedShot  Mallorca
# 18  MissedShots  Mallorca
